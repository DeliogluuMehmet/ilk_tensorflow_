# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("merc.csv")
df = df.copy()
df.head()
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 0        SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 1    S Class  2017  34948    Automatic    27000   Hybrid   20  61.4
# 2   SL CLASS  2016  49948    Automatic     6200   Petrol  555  28.0
# 3    G Class  2016  61948    Automatic    16000   Petrol  325  30.4
# 4    G Class  2016  73948    Automatic     4000   Petrol  325  30.1
#
#    engineSize
# 0         1.8
# 1         2.1
# 2         5.5
# 3         4.0
# 4         4.0

# %%
df.describe().T
# Out:
#               count          mean           std     min      25%      50%  \
# year        13119.0   2017.296288      2.224709  1970.0   2016.0   2018.0
# price       13119.0  24698.596920  11842.675542   650.0  17450.0  22480.0
# mileage     13119.0  21949.559037  21176.512267     1.0   6097.5  15189.0
# tax         13119.0    129.972178     65.260286     0.0    125.0    145.0
# mpg         13119.0     55.155843     15.220082     1.1     45.6     56.5
# engineSize  13119.0      2.071530      0.572426     0.0      1.8      2.0
#
#                 75%       max
# year         2019.0    2020.0
# price       28980.0  159999.0
# mileage     31779.5  259000.0
# tax           145.0     580.0
# mpg            64.2     217.3
# engineSize      2.1       6.2

# %%
df.isna().sum()
# Out:
# model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %%
sns.distplot(df['price'])
# Out:
# C:\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
sns.countplot(df["year"])
# Out:
# C:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='year', ylabel='count'>

# %%
df.corr()
# Out:
#                 year     price   mileage       tax       mpg  engineSize
# year        1.000000  0.520712 -0.738027  0.012480 -0.094626   -0.142147
# price       0.520712  1.000000 -0.537214  0.268717 -0.438445    0.516126
# mileage    -0.738027 -0.537214  1.000000 -0.160223  0.202850    0.063652
# tax         0.012480  0.268717 -0.160223  1.000000 -0.513742    0.338341
# mpg        -0.094626 -0.438445  0.202850 -0.513742  1.000000   -0.339862
# engineSize -0.142147  0.516126  0.063652  0.338341 -0.339862    1.000000

# %%
df.corr()["price"].sort_values()
# Out:
# mileage      -0.537214
# mpg          -0.438445
# tax           0.268717
# engineSize    0.516126
# year          0.520712
# price         1.000000
# Name: price, dtype: float64

# %%
sns.scatterplot(x = 'mileage' , y = 'price' , data = df)
# Out:
# <AxesSubplot:xlabel='mileage', ylabel='price'>

# %%
df.sort_values("price" , ascending = False).head(20)
# Out:
#            model  year   price transmission  mileage fuelType  tax   mpg  \
# 6199     G Class  2020  159999    Semi-Auto     1350   Petrol  145  21.4
# 10044    G Class  2020  154998    Automatic     3000   Petrol  150  21.4
# 5       SL CLASS  2011  149948    Automatic     3000   Petrol  570  21.4
# 8737     A Class  2019  140319    Semi-Auto      785   Petrol  150  22.1
# 6386     G Class  2018  139995    Semi-Auto    13046   Petrol  145  21.4
# 8        G Class  2019  139948    Automatic    12000   Petrol  145  21.4
# 9133     A Class  2019  139559    Semi-Auto     1000   Petrol  145  22.1
# 8821     A Class  2020  138439    Semi-Auto     1000   Petrol  145  22.1
# 5902     G Class  2018  135771    Semi-Auto    19000   Petrol  145  21.4
# 7864     G Class  2018  135124    Semi-Auto    18234   Petrol  150  21.4
# 8673     A Class  2019  134219    Semi-Auto     1000   Petrol  145  24.8
# 6210     A Class  2019  129990    Automatic     1000   Petrol  145  24.8
# ...

# %%
len(df)
# Out:
# 13119

# %%
len(df) * 0.01
# Out:
# 131.19

# %% [markdown]
# fiyatı yüksek olan %1 lik kısmı çıkarıyoruz.

# %%
data = df.sort_values("price" , ascending = False).iloc[131:]

# %%
data.describe().T
# Out:
#               count          mean           std     min        25%      50%  \
# year        12988.0   2017.281876      2.228515  1970.0   2016.000   2018.0
# price       12988.0  24074.926933   9866.224575   650.0  17357.500  22299.0
# mileage     12988.0  22132.741146  21196.776401     1.0   6322.000  15369.5
# tax         12988.0    129.689714     65.183076     0.0    125.000    145.0
# mpg         12988.0     55.437142     15.025999     1.1     45.600     56.5
# engineSize  12988.0      2.050901      0.532596     0.0      1.675      2.0
#
#                  75%       max
# year         2019.00    2020.0
# price       28706.00   65990.0
# mileage     31982.25  259000.0
# tax           145.00     580.0
# mpg            64.20     217.3
# engineSize      2.10       6.2

# %%
sns.distplot(data['price'])
# Out:
# C:\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
df.groupby("year").mean()["price"]
# Out:
# year
# 1970    24999.000000
# 1997     9995.000000
# 1998     8605.000000
# 1999     5995.000000
# 2000     5743.333333
# 2001     4957.900000
# 2002     5820.444444
# 2003     4878.000000
# 2004     4727.615385
# 2005     4426.111111
# 2006     4036.875000
# 2007     5136.045455
# 2008     6967.437500
# 2009     6166.764706
# 2010     8308.473684
# 2011    12624.894737
# 2012    10845.140351
# 2013    11939.842466
# 2014    14042.936864
# 2015    16731.780020
# 2016    19307.892948
# 2017    21514.307854
# 2018    25720.162918
# 2019    31290.020865
# 2020    35433.282337
# Name: price, dtype: float64

# %%
data.groupby("year").mean()["price"]
# Out:
# year
# 1970    24999.000000
# 1997     9995.000000
# 1998     8605.000000
# 1999     5995.000000
# 2000     5743.333333
# 2001     4957.900000
# 2002     5820.444444
# 2003     4878.000000
# 2004     4727.615385
# 2005     4426.111111
# 2006     4036.875000
# 2007     5136.045455
# 2008     6967.437500
# 2009     6166.764706
# 2010     8308.473684
# 2011     8913.459459
# 2012    10845.140351
# 2013    11939.842466
# 2014    14042.936864
# 2015    16647.822222
# 2016    19223.558943
# 2017    21356.280421
# 2018    24800.844506
# 2019    30289.524832
# 2020    34234.794872
# Name: price, dtype: float64

# %% [raw]
# data[data.year != 1970].groupby("year").mean()["price"]

# %%
data = data[data.year != 1970]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
data["model"] = le.fit_transform(data["model"])
data["transmission"] = le.fit_transform(data["transmission"])
data["fuelType"] = le.fit_transform(data["fuelType"])

# %%
y = data["price"].values
X = data.drop("price" , axis=1).values

# %%
y
# Out:
# array([65990, 65990, 65980, ...,  1490,  1350,   650], dtype=int64)

# %%
X
# Out:
# array([[1.500e+01, 2.019e+03, 3.000e+00, ..., 1.500e+02, 3.040e+01,
#         3.000e+00],
#        [2.000e+00, 2.020e+03, 3.000e+00, ..., 1.450e+02, 2.800e+01,
#         4.000e+00],
#        [2.000e+00, 2.020e+03, 3.000e+00, ..., 1.450e+02, 2.800e+01,
#         4.000e+00],
#        ...,
#        [2.000e+01, 2.000e+03, 0.000e+00, ..., 2.650e+02, 2.720e+01,
#         3.200e+00],
#        [0.000e+00, 2.010e+03, 1.000e+00, ..., 1.450e+02, 5.430e+01,
#         2.000e+00],
#        [0.000e+00, 2.003e+03, 1.000e+00, ..., 2.350e+02, 4.000e+01,
#         1.400e+00]])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(X , y , test_size=0.3 , random_state=10)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
x_train = scaler.fit_transform(x_train)
x_test  = scaler.transform(x_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()

model.add(Dense(12 , activation = "relu"))
model.add(Dense(12 , activation = "relu"))
model.add(Dense(12 , activation = "relu"))
model.add(Dense(12 , activation = "relu"))

model.add(Dense(1))

model.compile(optimizer = "adam" , loss = "mse")

# %%
model.fit(x = x_train , y = y_train , validation_data = (x_test , y_test) , batch_size = 250 , epochs = 300)
# Out:
# Epoch 1/300
# 37/37 [==============================] - 1s 10ms/step - loss: 672151040.0000 - val_loss: 688108032.0000
# Epoch 2/300
# 37/37 [==============================] - 0s 4ms/step - loss: 672129984.0000 - val_loss: 688073664.0000
# Epoch 3/300
# 37/37 [==============================] - 0s 4ms/step - loss: 672063680.0000 - val_loss: 687952640.0000
# Epoch 4/300
# 37/37 [==============================] - 0s 4ms/step - loss: 671836672.0000 - val_loss: 687537088.0000
# Epoch 5/300
# 37/37 [==============================] - 0s 4ms/step - loss: 671083328.0000 - val_loss: 686241024.0000
# Epoch 6/300
# 37/37 [==============================] - 0s 4ms/step - loss: 668983680.0000 - val_loss: 682933248.0000
# Epoch 7/300
# 37/37 [==============================] - 0s 4ms/step - loss: 664069184.0000 - val_loss: 675613312.0000
# Epoch 8/300
# 37/37 [==============================] - 0s 4ms/step - loss: 653918784.0000 - val_loss: 661378240.0000
# Epoch 9/300
# ...

# %%
kayıp_veri = pd.DataFrame(model.history.history)
kayıp_veri
# Out:
#             loss     val_loss
# 0    672151040.0  688108032.0
# 1    672129984.0  688073664.0
# 2    672063680.0  687952640.0
# 3    671836672.0  687537088.0
# 4    671083328.0  686241024.0
# ..           ...          ...
# 295   16108332.0   17044760.0
# 296   16105353.0   17021110.0
# 297   16088558.0   17026690.0
# 298   16055430.0   17011632.0
# 299   16050163.0   16994820.0
#
# [300 rows x 2 columns]

# %%
kayıp_veri.plot()
# Out:
# <AxesSubplot:>

# %%
from sklearn.metrics import mean_squared_error , mean_absolute_error

# %%
tahmind = model.predict(x_test)

# %%
mean_absolute_error(y_test , tahmind)
# Out:
# 2904.812001929945

# %%
plt.scatter(y_test , tahmind)
plt.plot(y_test , y_test , "g-*")

# %%
yeni_araba = data.drop("price" , axis = 1).iloc[2]

yeni_araba = scaler.transform(yeni_araba.values.reshape(-1,8))

model.predict(yeni_araba)
# Out:
# array([[55865.39]], dtype=float32)

# %%
df.iloc[2]
# Out:
# model            SL CLASS
# year                 2016
# price               49948
# transmission    Automatic
# mileage              6200
# fuelType           Petrol
# tax                   555
# mpg                  28.0
# engineSize            5.5
# Name: 2, dtype: object
